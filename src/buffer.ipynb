# %%
pwd
# Out:
# '/root/nephos'

# %%
run makeWindsMap.py
# Out:
# 1485071100.0
# 1485069300.0
# 1485067500.0
# 1485065700.0
# 1485063900.0

# %%
# image = getImagesFromDB(collection, 1)
# xMax, yMax = getImageDimessions(image)[:2]
# plotDimensions = (xMax, yMax)
