# %%
pwd
# Out:
# '/root/nephos'

# %%
run makeWindsMap.py
# Out:
# 1487313900.0
# 1487312100.0
# 1487310300.0
# 1487308500.0
# 1487306700.0

# %%
# image = getImagesFromDB(collection, 1)
# xMax, yMax = getImageDimessions(image)[:2]
# plotDimensions = (xMax, yMax)
