# %%
import matplotlib.pyplot as plt

# %%
results = {'ORB_avn': [338, 341, 349, 333, 360, 381, 367, 361, 355, 366, 393, 397, 424, 422, 419, 424, 421, 417, 426, 421, 421, 431, 418, 420, 420, 425, 424, 422, 434, 421, 429, 415, 405, 403, 405, 407, 402, 397, 394, 404, 395, 392, 396, 406, 401, 406, 413, 418], 'SIFT_avn': [330, 328, 387, 401, 433, 424, 426, 388, 368, 410, 420, 455, 445, 513, 483, 504, 483, 523, 534, 609, 568, 571, 559, 557, 569, 532, 580, 557, 553, 530, 492, 489, 432, 476, 482, 416, 408, 447, 409, 431, 430, 446, 496, 519, 543, 542, 517, 503], 'SURF_avn': [307, 285, 311, 331, 336, 360, 350, 356, 358, 368, 374, 416, 449, 442, 378, 375, 429, 434, 453, 466, 461, 444, 457, 418, 447, 440, 434, 453, 417, 398, 390, 384, 374, 373, 395, 372, 360, 368, 361, 366, 378, 363, 396, 418, 398, 423, 416, 411]}

# %%
ts = pd.DataFrame.from_dict(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9ee084415464> in <module>()
# ----> 1 ts = pd.DataFrame.from_dict(results)
#
# NameError: name 'pd' is not defined

# %%
ts.plot()

# %%
plt.show()

# %%
run ../src/findingTest.py

# %%
ts.size
# Out:
# 600

# %%
ts['ORB'].size
# Out:
# 10

# %%
a = np.zeros((3,4))

# %%
f = a.flatten()

# %%
a[2, 1] = 2

# %%
((f > 1) & (f < 5)).sum()
# Out:
# 2

# %%
pd.date_range('1/1/2011 00:00:00', periods=10, freq='m')
# Out:
# DatetimeIndex(['2011-01-31', '2011-02-28', '2011-03-31', '2011-04-30',
#                '2011-05-31', '2011-06-30', '2011-07-31', '2011-08-31',
#                '2011-09-30', '2011-10-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts.set_index(pd.date_range('1/1/2011 00:00:00', periods=10, freq='45min')).plot(); plt.show()

# %%
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
ts.plot(); plt.show()

# %%
dates = pd.date_range('1/1/2011 00:00:00', periods=100, freq='45min')
serieT = pd.Series(np.random.randn(100), dates)
serieT.plot()
plt.show()

# %%
serieT

# %%
ts.hist(figsize=(30, 30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff04091fdd8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff03b18e7b8>]], dtype=object)

# %%
plt.show()

# %%
plt.savefig("histograms.svg")

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-d6ac987968b6> in <module>()
# ----> 1 import pandas
#
# ImportError: No module named 'pandas'

# %%
pd.Timestamp(datetime.datetime.fromtimestamp(1484986500))
# Out:
# Timestamp('2017-01-21 08:15:00')

# %%
import datetime

# %%
plt.plot(ts, )
# Out:
# <bound method DataFrame.get_value of    ORB  SIFT  SURF
# 0  406   712   554
# 1  409   736   641
# 2  413   774   646
# 3  417   840   627
# 4  424   872   592
# 5  430   868   668
# 6  436   985   636
# 7  422   926   651
# 8  423   930   611
# 9  425   970   678>
